# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("./nifty50/LT.csv")
dataset
# Out:
#             Date Symbol Series  Prev Close    Open     High      Low     Last  \
# 0     2004-06-23     LT     EQ        2.00   500.0   745.00   150.00   638.00
# 1     2004-06-24     LT     EQ      635.95   630.0   630.00   608.40   612.00
# 2     2004-06-25     LT     EQ      616.00   619.0   679.00   616.10   665.00
# 3     2004-06-28     LT     EQ      668.30   660.0   671.90   640.20   653.00
# 4     2004-06-29     LT     EQ      656.40   656.0   683.40   653.00   666.85
# ...          ...    ...    ...         ...     ...      ...      ...      ...
# 4077  2020-11-23     LT     EQ     1132.30  1138.8  1147.85  1122.85  1125.10
# 4078  2020-11-24     LT     EQ     1125.85  1135.0  1144.00  1128.30  1137.00
# 4079  2020-11-25     LT     EQ     1135.50  1141.5  1147.80  1112.45  1117.20
# 4080  2020-11-26     LT     EQ     1116.00  1130.0  1134.95  1101.55  1119.20
# 4081  2020-11-27     LT     EQ     1118.85  1129.0  1139.80  1092.00  1106.00
#
#         Close     VWAP    Volume      Turnover    Trades  Deliverable Volume  \
# 0      635.95   627.71   2699293  1.694372e+14       NaN              395612
# 1      616.00   618.21    913575  5.647802e+13       NaN              305751
# 2      668.30   658.45   1637383  1.078136e+14       NaN              217950
# 3      656.40   657.39    913349  6.004271e+13       NaN              194984
# 4      671.70   675.11    743063  5.016488e+13       NaN              101786
# ...       ...      ...       ...           ...       ...                 ...
# 4077  1125.85  1132.87   4998877  5.663065e+14  117426.0             2145194
# 4078  1135.50  1135.80   4623887  5.251822e+14  127581.0             2134296
# 4079  1116.00  1124.96   4651911  5.233236e+14  122884.0             1515634
# 4080  1118.85  1116.91   7360928  8.221465e+14  153742.0             3010531
# 4081  1122.40  1124.39  18995549  2.135842e+15  196120.0            15569906
#
#       %Deliverble
# 0          0.1466
# 1          0.3347
# 2          0.1331
# 3          0.2135
# 4          0.1370
# ...           ...
# 4077       0.4291
# 4078       0.4616
# 4079       0.3258
# 4080       0.4090
# 4081       0.8197
#
# [4082 rows x 15 columns]

# %%
dataset.isnull().sum()
# Out:
# Date                     0
# Symbol                   0
# Series                   0
# Prev Close               0
# Open                     0
# High                     0
# Low                      0
# Last                     0
# Close                    0
# VWAP                     0
# Volume                   0
# Turnover                 0
# Trades                1728
# Deliverable Volume       0
# %Deliverble              0
# dtype: int64

# %%
dataset.dropna(inplace=True)
dataset
# Out:
#             Date Symbol Series  Prev Close     Open     High      Low  \
# 1728  2011-06-01     LT     EQ     1642.35  1642.00  1689.00  1641.55
# 1729  2011-06-02     LT     EQ     1684.95  1665.20  1677.75  1654.25
# 1730  2011-06-03     LT     EQ     1672.10  1681.00  1719.70  1680.50
# 1731  2011-06-06     LT     EQ     1712.75  1700.00  1736.05  1699.10
# 1732  2011-06-07     LT     EQ     1727.80  1721.45  1726.40  1697.50
# ...          ...    ...    ...         ...      ...      ...      ...
# 4077  2020-11-23     LT     EQ     1132.30  1138.80  1147.85  1122.85
# 4078  2020-11-24     LT     EQ     1125.85  1135.00  1144.00  1128.30
# 4079  2020-11-25     LT     EQ     1135.50  1141.50  1147.80  1112.45
# 4080  2020-11-26     LT     EQ     1116.00  1130.00  1134.95  1101.55
# 4081  2020-11-27     LT     EQ     1118.85  1129.00  1139.80  1092.00
#
#          Last    Close     VWAP    Volume      Turnover    Trades  \
# 1728  1686.40  1684.95  1672.76   1875422  3.137129e+14  110884.0
# 1729  1674.20  1672.10  1666.21   1433110  2.387863e+14   54940.0
# 1730  1714.35  1712.75  1705.57   2771995  4.727834e+14   83507.0
# 1731  1726.00  1727.80  1719.47   1231355  2.117274e+14   59907.0
# 1732  1706.00  1705.60  1708.21   1245656  2.127836e+14   51705.0
# ...       ...      ...      ...       ...           ...       ...
# 4077  1125.10  1125.85  1132.87   4998877  5.663065e+14  117426.0
# 4078  1137.00  1135.50  1135.80   4623887  5.251822e+14  127581.0
# 4079  1117.20  1116.00  1124.96   4651911  5.233236e+14  122884.0
# 4080  1119.20  1118.85  1116.91   7360928  8.221465e+14  153742.0
# 4081  1106.00  1122.40  1124.39  18995549  2.135842e+15  196120.0
#
#       Deliverable Volume  %Deliverble
# 1728              835150       0.4453
# 1729              770133       0.5374
# 1730             1672339       0.6033
# 1731              478964       0.3890
# 1732              617338       0.4956
# ...                  ...          ...
# 4077             2145194       0.4291
# 4078             2134296       0.4616
# 4079             1515634       0.3258
# 4080             3010531       0.4090
# 4081            15569906       0.8197
#
# [2354 rows x 15 columns]

# %%
dataset.columns
# Out:
# Index(['Date', 'Symbol', 'Series', 'Prev Close', 'Open', 'High', 'Low', 'Last',
#        'Close', 'VWAP', 'Volume', 'Turnover', 'Trades', 'Deliverable Volume',
#        '%Deliverble'],
#       dtype='object')

# %%
to_drop = ['Date', 'Symbol', 'Series']
dataset = dataset.drop(columns = to_drop)
dataset
# Out:
#       Prev Close     Open     High      Low     Last    Close     VWAP  \
# 1728     1642.35  1642.00  1689.00  1641.55  1686.40  1684.95  1672.76
# 1729     1684.95  1665.20  1677.75  1654.25  1674.20  1672.10  1666.21
# 1730     1672.10  1681.00  1719.70  1680.50  1714.35  1712.75  1705.57
# 1731     1712.75  1700.00  1736.05  1699.10  1726.00  1727.80  1719.47
# 1732     1727.80  1721.45  1726.40  1697.50  1706.00  1705.60  1708.21
# ...          ...      ...      ...      ...      ...      ...      ...
# 4077     1132.30  1138.80  1147.85  1122.85  1125.10  1125.85  1132.87
# 4078     1125.85  1135.00  1144.00  1128.30  1137.00  1135.50  1135.80
# 4079     1135.50  1141.50  1147.80  1112.45  1117.20  1116.00  1124.96
# 4080     1116.00  1130.00  1134.95  1101.55  1119.20  1118.85  1116.91
# 4081     1118.85  1129.00  1139.80  1092.00  1106.00  1122.40  1124.39
#
#         Volume      Turnover    Trades  Deliverable Volume  %Deliverble
# 1728   1875422  3.137129e+14  110884.0              835150       0.4453
# 1729   1433110  2.387863e+14   54940.0              770133       0.5374
# 1730   2771995  4.727834e+14   83507.0             1672339       0.6033
# 1731   1231355  2.117274e+14   59907.0              478964       0.3890
# 1732   1245656  2.127836e+14   51705.0              617338       0.4956
# ...        ...           ...       ...                 ...          ...
# 4077   4998877  5.663065e+14  117426.0             2145194       0.4291
# 4078   4623887  5.251822e+14  127581.0             2134296       0.4616
# 4079   4651911  5.233236e+14  122884.0             1515634       0.3258
# 4080   7360928  8.221465e+14  153742.0             3010531       0.4090
# 4081  18995549  2.135842e+15  196120.0            15569906       0.8197
#
# [2354 rows x 12 columns]

# %% [markdown]
# ## input features and target

# %%
dataset.columns
# Out:
# Index(['Prev Close', 'Open', 'High', 'Low', 'Last', 'Close', 'VWAP', 'Volume',
#        'Turnover', 'Trades', 'Deliverable Volume', '%Deliverble'],
#       dtype='object')

# %%
tar_col = ['VWAP']
Y = dataset[tar_col]
Y
# Out:
#          VWAP
# 1728  1672.76
# 1729  1666.21
# 1730  1705.57
# 1731  1719.47
# 1732  1708.21
# ...       ...
# 4077  1132.87
# 4078  1135.80
# 4079  1124.96
# 4080  1116.91
# 4081  1124.39
#
# [2354 rows x 1 columns]

# %%
X = dataset.drop(columns = tar_col)
X
# Out:
#       Prev Close     Open     High      Low     Last    Close    Volume  \
# 1728     1642.35  1642.00  1689.00  1641.55  1686.40  1684.95   1875422
# 1729     1684.95  1665.20  1677.75  1654.25  1674.20  1672.10   1433110
# 1730     1672.10  1681.00  1719.70  1680.50  1714.35  1712.75   2771995
# 1731     1712.75  1700.00  1736.05  1699.10  1726.00  1727.80   1231355
# 1732     1727.80  1721.45  1726.40  1697.50  1706.00  1705.60   1245656
# ...          ...      ...      ...      ...      ...      ...       ...
# 4077     1132.30  1138.80  1147.85  1122.85  1125.10  1125.85   4998877
# 4078     1125.85  1135.00  1144.00  1128.30  1137.00  1135.50   4623887
# 4079     1135.50  1141.50  1147.80  1112.45  1117.20  1116.00   4651911
# 4080     1116.00  1130.00  1134.95  1101.55  1119.20  1118.85   7360928
# 4081     1118.85  1129.00  1139.80  1092.00  1106.00  1122.40  18995549
#
#           Turnover    Trades  Deliverable Volume  %Deliverble
# 1728  3.137129e+14  110884.0              835150       0.4453
# 1729  2.387863e+14   54940.0              770133       0.5374
# 1730  4.727834e+14   83507.0             1672339       0.6033
# 1731  2.117274e+14   59907.0              478964       0.3890
# 1732  2.127836e+14   51705.0              617338       0.4956
# ...            ...       ...                 ...          ...
# 4077  5.663065e+14  117426.0             2145194       0.4291
# 4078  5.251822e+14  127581.0             2134296       0.4616
# 4079  5.233236e+14  122884.0             1515634       0.3258
# 4080  8.221465e+14  153742.0             3010531       0.4090
# 4081  2.135842e+15  196120.0            15569906       0.8197
#
# [2354 rows x 11 columns]

# %%
for feature_name in X:
    plt.figure(figsize=(7,5))
    plt.tight_layout()
    plt.scatter(X[feature_name], Y)
    plt.ylabel(tar_col[0],size = 25)
    plt.xlabel(feature_name, size = 25)
    plt.show()

# %%
X = np.array(X)
#X
X.shape
# Out:
# (2354, 11)

# %%
Y = np.array(Y)
#Y
Y.shape
# Out:
# (2354, 1)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.20)

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.fit_transform(X_test)

# %% [markdown]
# # linear regression

# %%
from sklearn.linear_model import LinearRegression

reg = LinearRegression().fit(X_train, Y_train)
reg.score(X_train, Y_train)
# Out:
# 0.9997566497442919

# %%
reg.score(X_test, Y_test)
# Out:
# 0.9985862455806532

# %%
reg.coef_
# Out:
# array([[ -0.87789375,   1.2907002 , 109.07598732,  61.99802236,
#         -63.93575857, 136.56410674,  -1.1102689 ,   2.38027952,
#          -1.11659425,  -1.05925399,   0.41296086]])

# %%
reg.intercept_
# Out:
# array([1361.23888476])

# %%
reg.predict(X)
# Out:
# array([[7.46724353e+14],
#        [5.68378233e+14],
#        [1.12535659e+15],
#        ...,
#        [1.24565652e+15],
#        [1.95693854e+15],
#        [5.08389983e+15]])
